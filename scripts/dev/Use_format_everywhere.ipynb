# %%
from epformatline.worker import translate

# %%
from pathlib import Path
import re
import subprocess
from typing import Optional, List

import difflib as dl

# %%
ROOT_DIR = Path('../../').resolve()

# %%
EP_SRC = ROOT_DIR / 'src/EnergyPlus'

# %% [markdown]
# # Regex-fu

# %%
FUNCTION_NAMES = [
    'ShowFatalError',
    'ShowSevereError',
    'ShowSevereMessage',
    'ShowContinueError',
    'ShowContinueErrorTimeStamp',
    'ShowMessage',
    'ShowWarningError',
    'ShowWarningMessage',
    'ShowErrorMessage',
]

RECURRING_FUNCTION_NAMES = [
    'ShowRecurringSevereErrorAtEnd',
    'ShowRecurringWarningErrorAtEnd',
    'ShowRecurringContinueErrorAtEnd',
    'StoreRecurringErrorMessage',
]

# %%
func_pattern = rf"(?P<function>{'|'.join(FUNCTION_NAMES)})"
func_pattern
# Out:
# '(?P<function>ShowFatalError|ShowSevereError|ShowSevereMessage|ShowContinueError|ShowContinueErrorTimeStamp|ShowMessage|ShowWarningError|ShowWarningMessage|ShowErrorMessage)'

# %%
RE_MESSAGE = re.compile(
    func_pattern +
    r'\s*?\(\s*?(?P<state>\w+)\s*?,\s+(?P<input>.*?)\s*?\);',
    flags=re.DOTALL | re.MULTILINE
)

# %%
RE_MESSAGE
# Out:
# re.compile(r'(?P<function>ShowFatalError|ShowSevereError|ShowSevereMessage|ShowContinueError|ShowContinueErrorTimeStamp|ShowMessage|ShowWarningError|ShowWarningMessage|ShowErrorMessage)\s*?\(\s*?(?P<state>\w+)\s*?,\s+(?P<input>.*?)\s*?\);',
# re.MULTILINE|re.DOTALL|re.UNICODE)

# %%
def replace_fun(matchobj):
    d = matchobj.groupdict()
    input_str = d['input'].strip()
    if input_str.startswith('format') or input_str.startswith('fmt::format') or not '+' in input_str:
        return matchobj.group(0) # No-op
    return f"{d['function']}({d['state']}, {translate(input_str)});"

# %% [markdown]
# # Test content

# %%
test_content = r"""
        //   Warn user if curve output goes negative
        if (TotCoolCapTempModFac < 0.0) {
            if (!state.dataGlobal->WarmupFlag && NumTUInCoolingMode > 0) {
                if (vrf.CoolCapFTErrorIndex == 0) {
                    ShowSevereMessage(state, std::string(cVRFTypes(VRF_HeatPump)) + " \"" + vrf.Name + "\":");
                    ShowContinueError(
                        state,
                        format(" Cooling Capacity Modifier curve (function of temperature) output is negative ({:.3T}).", TotCoolCapTempModFac));
                    ShowContinueError(state,
                                      format(" Negative value occurs using an outdoor air temperature of {:.1T} C and an average indoor air "
                                             "wet-bulb temperature of {:.1T} C.",
                                             CondInletTemp,
                                             InletAirWetBulbC));
                    ShowContinueErrorTimeStamp(state, " Resetting curve output to zero and continuing simulation.");
                }
                ShowRecurringWarningErrorAtEnd(
                    state,
                    format("{} \"{}\": Cooling Capacity Modifier curve (function of temperature) output is negative warning continues...",
                           PlantEquipTypeNames[static_cast<int>(PlantEquipmentType::HeatPumpVRF)],
                           vrf.Name),
                    vrf.CoolCapFTErrorIndex,
                    TotCoolCapTempModFac,
                    TotCoolCapTempModFac);
                TotCoolCapTempModFac = 0.0;
            }
        }"""

# %%
print(RE_MESSAGE.sub(replace_fun, test_content))
# Out:
#         //   Warn user if curve output goes negative
#         if (TotCoolCapTempModFac < 0.0) {
#             if (!state.dataGlobal->WarmupFlag && NumTUInCoolingMode > 0) {
#                 if (vrf.CoolCapFTErrorIndex == 0) {
#                     ShowSevereMessage(state, format("{} \"{}\":", cVRFTypes(VRF_HeatPump), vrf.Name));
#                     ShowContinueError(
#                         state,
#                         format(" Cooling Capacity Modifier curve (function of temperature) output is negative ({:.3T}).", TotCoolCapTempModFac));
#                     ShowContinueError(state,
#                                       format(" Negative value occurs using an outdoor air temperature of {:.1T} C and an average indoor air "
#                                              "wet-bulb temperature of {:.1T} C.",
#                                              CondInletTemp,
#                                              InletAirWetBulbC));
#                     ShowContinueErrorTimeStamp(state, " Resetting curve output to zero and continuing simulation.");
#                 }
#                 ShowRecurringWarningErrorAtEnd(
#                     state,
#                     format("{} \"{}\": Cooling Capacity Modifier curve (function of temperature) output is negative warning continues...",
#                            PlantEquipTypeNames[static_cast<int>(PlantEquipmentType::HeatPumpVRF)],
#                            vrf.Name),
#                     vrf.CoolCapFTErrorIndex,
#                     TotCoolCapTempModFac,
#                     TotCoolCapTempModFac);
#                 TotCoolCapTempModFac = 0.0;
#             }
#         }

# %% [markdown]
# # Try on a single file

# %%
def clang_format(fpath: Path):
    subprocess.check_call(['clang-format-11', '--style=file', '-i', str(fpath)])

# %%
def strip(lines):
    return [x.strip() for x in lines]

class ReportInfo:
    def __init__(self, file: Path, lines: [str], fixed_lines: [str]):
        self.file = file
        self.lines = lines
        self.fixed_lines = fixed_lines
        self.num_lines_changed = len(set(fixed_lines) - set(lines))
    
    def show_diff(self, style_output: bool = False, dedent: bool = True, use_generator: bool = False, width: int = None):
        
        if dedent:
            diffs = dl.unified_diff(strip(self.lines), strip(self.fixed_lines), n=0, lineterm="")
        else:
            diffs = dl.unified_diff(self.lines, self.fixed_lines, n=0, lineterm="")

        if width is None:
            width = 115
        
        if style_output:
            from rich.console import Console
            from rich.syntax import Syntax
            console = Console(width=width)
            if use_generator:
                for diff in diffs:
                    syntax = Syntax(diff, "Diff", theme="", line_numbers=False, word_wrap=True)
                    console.print(syntax)
            else:
                all_diff = "\n".join(list(diffs))
                syntax = Syntax(all_diff, "Diff", theme="", line_numbers=False, word_wrap=True)
                console.print(syntax)
        else:
            if use_generator:
                for diff in diffs:
                    print(diff)
            else:
                all_diff = "\n".join(list(diffs))
                print(all_diff)
        
    def __repr__(self):
        return f"{self.file.relative_to(ROOT_DIR)}: {self.num_lines_changed} changes"

def fix_format_in_file(file: Path, inplace: bool = True, reformat: bool = True) -> Optional[ReportInfo]:
    with open(file, 'r') as f:
        content = f.read()
    if not(any(x in content for x in FUNCTION_NAMES)):
        # print(f"Skipping {file}, no print function in there")
        return
    fixed_content = RE_MESSAGE.sub(replace_fun, content)
    fixed_lines = fixed_content.splitlines()
    if inplace:
        with open(file, 'w') as f:
            f.write(fixed_content)
            if reformat:
                clang_format(file)
        
    lines = content.splitlines()
    fixed_lines = fixed_content.splitlines()
    return ReportInfo(file=file, lines=lines, fixed_lines=fixed_lines)

# %%
fpath = EP_SRC / 'HVACVariableRefrigerantFlow.cc'
r = fix_format_in_file(file=fpath)

# %%
r
# Out:
# src/EnergyPlus/HVACVariableRefrigerantFlow.cc: 200 changes

# %%
width = None
r.show_diff(style_output=True, dedent=True, width=width)
# Out:
# ---
# +++
# @@ -170 +170 @@
# -ShowFatalError(state, "SimulateVRF: VRF Terminal Unit not found=" + std::string{CompName});
# +ShowFatalError(state, format("SimulateVRF: VRF Terminal Unit not found={}", CompName));
# @@ -300 +300 @@
# -ShowFatalError(state, "LocalVRFCondenserFactory: Error getting inputs for object named: " + objectName); //
# LCOV_EXCL_LINE
# +ShowFatalError(state, format("LocalVRFCondenserFactory: Error getting inputs for object named: {}", objectName));
# // LCOV_EXCL_LINE
# @@ -341 +341 @@
# -ShowFatalError(state, "SimVRFCondenserPlant:: Invalid loop connection " + std::string(cVRFTypes(VRF_HeatPump)));
# +ShowFatalError(state, format("SimVRFCondenserPlant:: Invalid loop connection {}", cVRFTypes(VRF_HeatPump)));
# @@ -605 +605 @@
# -ShowSevereMessage(state, std::string(cVRFTypes(VRF_HeatPump)) + " \"" + vrf.Name + "\":");
# +ShowSevereMessage(state, format("{} \"{}\":", cVRFTypes(VRF_HeatPump), vrf.Name));
# @@ -632 +632 @@
# -ShowSevereMessage(state, std::string(cVRFTypes(VRF_HeatPump)) + " \"" + vrf.Name + "\":");
# +ShowSevereMessage(state, format("{} \"{}\":", cVRFTypes(VRF_HeatPump), vrf.Name));
# @@ -668 +668 @@
# -ShowSevereMessage(state, std::string(cVRFTypes(VRF_HeatPump)) + " \"" + vrf.Name + "\":");
# +ShowSevereMessage(state, format("{} \"{}\":", cVRFTypes(VRF_HeatPump), vrf.Name));
# @@ -694 +694 @@
# -ShowSevereMessage(state, std::string(cVRFTypes(VRF_HeatPump)) + " \"" + vrf.Name + "\":");
# +ShowSevereMessage(state, format("{} \"{}\":", cVRFTypes(VRF_HeatPump), vrf.Name));
# @@ -776 +776 @@
# -ShowSevereMessage(state, std::string(cVRFTypes(VRF_HeatPump)) + " \"" + vrf.Name + "\":");
# +ShowSevereMessage(state, format("{} \"{}\":", cVRFTypes(VRF_HeatPump), vrf.Name));
# @@ -818 +818 @@
# -ShowSevereMessage(state, std::string(cVRFTypes(VRF_HeatPump)) + " \"" + vrf.Name + "\":");
# +ShowSevereMessage(state, format("{} \"{}\":", cVRFTypes(VRF_HeatPump), vrf.Name));
# @@ -891 +891 @@
# -ShowSevereMessage(state, std::string(cVRFTypes(VRF_HeatPump)) + " \"" + vrf.Name + "\":");
# +ShowSevereMessage(state, format("{} \"{}\":", cVRFTypes(VRF_HeatPump), vrf.Name));
# @@ -1366,3 +1366 @@
# -ShowFatalError(state,
# -std::string{RoutineName} +
# -"Errors found in getting AirConditioner:VariableRefrigerantFlow system input. Preceding condition(s) causes
# termination.");
# +ShowFatalError(state, format("{}Errors found in getting AirConditioner:VariableRefrigerantFlow system input.
# Preceding condition(s) causes termination.", RoutineName));
# @@ -1640,2 +1638,2 @@
# -ShowSevereError(state, cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\" invalid
# data");
# -ShowContinueError(state, "Invalid-not found " + cAlphaFieldNames(2) + "=\"" + cAlphaArgs(2) + "\".");
# +ShowSevereError(state, format("{}=\"{}\" invalid data", cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("Invalid-not found {}=\"{}\".", cAlphaFieldNames(2), cAlphaArgs(2)));
# @@ -1798,3 +1796,2 @@
# -ShowWarningError(
# -state, std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\",
# invalid");
# -ShowContinueError(state, "..." + cAlphaFieldNames(12) + "=\"" + cAlphaArgs(12) + "\" has out of range values.");
# +ShowWarningError(state, format("{}{}=\"{}\", invalid", RoutineName, cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...{}=\"{}\" has out of range values.", cAlphaFieldNames(12), cAlphaArgs(12)));
# @@ -1808,3 +1805,2 @@
# -ShowWarningError(
# -state, std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\",
# invalid");
# -ShowContinueError(state, "..." + cAlphaFieldNames(12) + " = " + cAlphaArgs(12) + " has out of range value.");
# +ShowWarningError(state, format("{}{}=\"{}\", invalid", RoutineName, cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...{} = {} has out of range value.", cAlphaFieldNames(12), cAlphaArgs(12)));
# @@ -1828 +1824 @@
# -ShowSevereError(state, cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\"");
# +ShowSevereError(state, format("{}, \"{}\"", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# @@ -1936,3 +1932 @@
# -ShowSevereError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\" illegal " + cAlphaFieldNames(19)
# +
# -" input for this object = " + cAlphaArgs(19));
# +ShowSevereError(state, format("{}, \"{}\" illegal {} input for this object = {}", cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name, cAlphaFieldNames(19), cAlphaArgs(19)));
# @@ -2006,3 +2000,2 @@
# -ShowWarningError(
# -state, std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\",
# invalid");
# -ShowContinueError(state, "..." + cAlphaFieldNames(23) + "=\"" + cAlphaArgs(23) + "\" has out of range values.");
# +ShowWarningError(state, format("{}{}=\"{}\", invalid", RoutineName, cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...{}=\"{}\" has out of range values.", cAlphaFieldNames(23), cAlphaArgs(23)));
# @@ -2016,3 +2009,2 @@
# -ShowWarningError(
# -state, std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\",
# invalid");
# -ShowContinueError(state, "..." + cAlphaFieldNames(23) + " = " + cAlphaArgs(23) + " has out of range value.");
# +ShowWarningError(state, format("{}{}=\"{}\", invalid", RoutineName, cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...{} = {} has out of range value.", cAlphaFieldNames(23), cAlphaArgs(23)));
# @@ -2034,3 +2026,2 @@
# -ShowWarningError(
# -state, std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\",
# invalid");
# -ShowContinueError(state, "..." + cAlphaFieldNames(9) + " = " + cAlphaArgs(9) + " has out of range value.");
# +ShowWarningError(state, format("{}{}=\"{}\", invalid", RoutineName, cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...{} = {} has out of range value.", cAlphaFieldNames(9), cAlphaArgs(9)));
# @@ -2044,3 +2035,2 @@
# -ShowWarningError(
# -state, std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\",
# suspicious");
# -ShowContinueError(state, "..." + cAlphaFieldNames(9) + " = " + cAlphaArgs(9) + " has unexpected value.");
# +ShowWarningError(state, format("{}{}=\"{}\", suspicious", RoutineName, cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...{} = {} has unexpected value.", cAlphaFieldNames(9), cAlphaArgs(9)));
# @@ -2057,3 +2047,2 @@
# -ShowWarningError(
# -state, std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\",
# invalid");
# -ShowContinueError(state, "..." + cAlphaFieldNames(20) + " = " + cAlphaArgs(20) + " has out of range value.");
# +ShowWarningError(state, format("{}{}=\"{}\", invalid", RoutineName, cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...{} = {} has out of range value.", cAlphaFieldNames(20), cAlphaArgs(20)));
# @@ -2067,3 +2056,2 @@
# -ShowWarningError(
# -state, std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\",
# suspicious");
# -ShowContinueError(state, "..." + cAlphaFieldNames(20) + " = " + cAlphaArgs(20) + " has unexpected value.");
# +ShowWarningError(state, format("{}{}=\"{}\", suspicious", RoutineName, cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...{} = {} has unexpected value.", cAlphaFieldNames(20), cAlphaArgs(20)));
# @@ -2089,2 +2077,2 @@
# -ShowSevereError(state, cCurrentModuleObject + " = \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\"");
# -ShowContinueError(state, cAlphaFieldNames(24) + " must be entered when " + cAlphaFieldNames(25) + " = " +
# cAlphaArgs(25));
# +ShowSevereError(state, format("{} = \"{}\"", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("{} must be entered when {} = {}", cAlphaFieldNames(24), cAlphaFieldNames(25),
# cAlphaArgs(25)));
# @@ -2094,2 +2082,2 @@
# -ShowSevereError(state, cCurrentModuleObject + " = " + state.dataHVACVarRefFlow->VRF(VRFNum).Name);
# -ShowContinueError(state, "Illegal " + cAlphaFieldNames(25) + " = " + cAlphaArgs(25));
# +ShowSevereError(state, format("{} = {}", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("Illegal {} = {}", cAlphaFieldNames(25), cAlphaArgs(25)));
# @@ -2102,3 +2090,3 @@
# -ShowSevereError(state, cCurrentModuleObject + " = " + state.dataHVACVarRefFlow->VRF(VRFNum).Name);
# -ShowContinueError(state, "..." + cAlphaFieldNames(26) + " = " + cAlphaArgs(26) + " not found.");
# -ShowContinueError(state, "A schedule name is required when " + cAlphaFieldNames(25) + " = " + cAlphaArgs(25));
# +ShowSevereError(state, format("{} = {}", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...{} = {} not found.", cAlphaFieldNames(26), cAlphaArgs(26)));
# +ShowContinueError(state, format("A schedule name is required when {} = {}", cAlphaFieldNames(25),
# cAlphaArgs(25)));
# @@ -2112,2 +2100,2 @@
# -ShowSevereError(state, cCurrentModuleObject + " = \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\"");
# -ShowContinueError(state, cAlphaFieldNames(27) + " = " + cAlphaArgs(27) + " not found.");
# +ShowSevereError(state, format("{} = \"{}\"", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("{} = {} not found.", cAlphaFieldNames(27), cAlphaArgs(27)));
# @@ -2124,2 +2112,2 @@
# -ShowSevereError(state, cCurrentModuleObject + " = " + state.dataHVACVarRefFlow->VRF(VRFNum).Name);
# -ShowContinueError(state, "Illegal " + cAlphaFieldNames(28) + " = " + cAlphaArgs(28));
# +ShowSevereError(state, format("{} = {}", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("Illegal {} = {}", cAlphaFieldNames(28), cAlphaArgs(28)));
# @@ -2171,3 +2159 @@
# -ShowSevereError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\" " + cAlphaFieldNames(31) +
# -" not found: " + cAlphaArgs(31));
# +ShowSevereError(state, format("{}, \"{}\" {} not found: {}", cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name, cAlphaFieldNames(31), cAlphaArgs(31)));
# @@ -2186,3 +2172 @@
# -ShowSevereError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\" " + cAlphaFieldNames(32) +
# -" not found: " + cAlphaArgs(32));
# +ShowSevereError(state, format("{}, \"{}\" {} not found: {}", cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name, cAlphaFieldNames(32), cAlphaArgs(32)));
# @@ -2208,3 +2192 @@
# -ShowSevereError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\" " + cAlphaFieldNames(33) +
# -" not found:" + cAlphaArgs(33));
# +ShowSevereError(state, format("{}, \"{}\" {} not found:{}", cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name, cAlphaFieldNames(33), cAlphaArgs(33)));
# @@ -2216,3 +2198 @@
# -ShowSevereError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\" " + cAlphaFieldNames(33) +
# -" not found:" + cAlphaArgs(33));
# +ShowSevereError(state, format("{}, \"{}\" {} not found:{}", cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name, cAlphaFieldNames(33), cAlphaArgs(33)));
# @@ -2227,3 +2207 @@
# -ShowWarningError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\" " + cNumericFieldNames(21) +
# -" = 0.0 for defrost strategy = RESISTIVE.");
# +ShowWarningError(state, format("{}, \"{}\" {} = 0.0 for defrost strategy = RESISTIVE.", cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name, cNumericFieldNames(21)));
# @@ -2243,3 +2221,3 @@
# -ShowSevereError(state, cCurrentModuleObject + " = " + state.dataHVACVarRefFlow->VRF(VRFNum).Name);
# -ShowContinueError(state, cAlphaFieldNames(34) + " = " + cAlphaArgs(34));
# -ShowContinueError(state, "Illegal " + cAlphaFieldNames(19) + " input for this object = " + cAlphaArgs(19));
# +ShowSevereError(state, format("{} = {}", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("{} = {}", cAlphaFieldNames(34), cAlphaArgs(34)));
# +ShowContinueError(state, format("Illegal {} input for this object = {}", cAlphaFieldNames(19), cAlphaArgs(19)));
# @@ -2247 +2225 @@
# -ShowContinueError(state, "... " + cAlphaFieldNames(19) + " will be reset to DRYBULBTEMPERATURE and simulation
# continues.");
# +ShowContinueError(state, format("... {} will be reset to DRYBULBTEMPERATURE and simulation continues.",
# cAlphaFieldNames(19)));
# @@ -2251,2 +2229,2 @@
# -ShowSevereError(state, cCurrentModuleObject + " = " + state.dataHVACVarRefFlow->VRF(VRFNum).Name);
# -ShowContinueError(state, "Illegal " + cAlphaFieldNames(34) + " = " + cAlphaArgs(34));
# +ShowSevereError(state, format("{} = {}", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("Illegal {} = {}", cAlphaFieldNames(34), cAlphaArgs(34)));
# @@ -2277,3 +2255 @@
# -ShowSevereError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\" " + cAlphaFieldNames(35) +
# -" not a valid Outdoor Air Node = " + cAlphaArgs(35));
# +ShowSevereError(state, format("{}, \"{}\" {} not a valid Outdoor Air Node = {}", cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name, cAlphaFieldNames(35), cAlphaArgs(35)));
# @@ -2315,2 +2291 @@
# -ShowSevereError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\" " + cAlphaFieldNames(36) + " is
# blank.");
# +ShowSevereError(state, format("{}, \"{}\" {} is blank.", cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name, cAlphaFieldNames(36)));
# @@ -2323,4 +2298,2 @@
# -ShowSevereError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\" " + cNumericFieldNames(23) +
# -" is blank.");
# -ShowContinueError(state, "...input is required when " + cAlphaFieldNames(34) + " = " + cAlphaArgs(34));
# +ShowSevereError(state, format("{}, \"{}\" {} is blank.", cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name, cNumericFieldNames(23)));
# +ShowContinueError(state, format("...input is required when {} = {}", cAlphaFieldNames(34), cAlphaArgs(34)));
# @@ -2355,3 +2328 @@
# -ShowSevereError(state,
# -cCurrentModuleObject + " = \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", " + cNumericFieldNames(27) +
# -" must be >= 0");
# +ShowSevereError(state, format("{} = \"{}\", {} must be >= 0", cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name, cNumericFieldNames(27)));
# @@ -2367,3 +2338 @@
# -ShowWarningError(state,
# -cCurrentModuleObject + " = \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", " + cNumericFieldNames(28) +
# -" is less than 2 deg C. Freezing could occur.");
# +ShowWarningError(state, format("{} = \"{}\", {} is less than 2 deg C. Freezing could occur.",
# cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name, cNumericFieldNames(28)));
# @@ -2376,3 +2345 @@
# -ShowWarningError(state,
# -cCurrentModuleObject + " = \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", " + cAlphaFieldNames(38) +
# -" = \"" + cAlphaArgs(38) + "\" was not found.");
# +ShowWarningError(state, format("{} = \"{}\", {} = \"{}\" was not found.", cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name, cAlphaFieldNames(38), cAlphaArgs(38)));
# @@ -2390,3 +2357 @@
# -ShowSevereError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", " + cAlphaFieldNames(39) +
# -" not found = " + cAlphaArgs(39));
# +ShowSevereError(state, format("{}, \"{}\", {} not found = {}", cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name, cAlphaFieldNames(39), cAlphaArgs(39)));
# @@ -2408,3 +2373 @@
# -ShowWarningError(state,
# -cCurrentModuleObject + " = \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", " + cNumericFieldNames(29) +
# -" is less than the minimum temperature in heat pump mode.");
# +ShowWarningError(state, format("{} = \"{}\", {} is less than the minimum temperature in heat pump mode.",
# cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name, cNumericFieldNames(29)));
# @@ -2436,3 +2399 @@
# -ShowWarningError(state,
# -cCurrentModuleObject + " = \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", " + cNumericFieldNames(30) +
# -" is greater than the maximum temperature in heat pump mode.");
# +ShowWarningError(state, format("{} = \"{}\", {} is greater than the maximum temperature in heat pump mode.",
# cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name, cNumericFieldNames(30)));
# @@ -2556,2 +2517,2 @@
# -ShowSevereError(state, cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\" invalid
# data");
# -ShowContinueError(state, "Invalid-not found " + cAlphaFieldNames(2) + "=\"" + cAlphaArgs(2) + "\".");
# +ShowSevereError(state, format("{}=\"{}\" invalid data", cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("Invalid-not found {}=\"{}\".", cAlphaFieldNames(2), cAlphaArgs(2)));
# @@ -2565,2 +2526,2 @@
# -ShowSevereError(state, cCurrentModuleObject + " = \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\"");
# -ShowContinueError(state, cAlphaFieldNames(3) + " = " + cAlphaArgs(3) + " not found.");
# +ShowSevereError(state, format("{} = \"{}\"", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("{} = {} not found.", cAlphaFieldNames(3), cAlphaArgs(3)));
# @@ -2579,2 +2540,2 @@
# -ShowSevereError(state, cCurrentModuleObject + " = " + state.dataHVACVarRefFlow->VRF(VRFNum).Name);
# -ShowContinueError(state, "Illegal " + cAlphaFieldNames(4) + " = " + cAlphaArgs(4));
# +ShowSevereError(state, format("{} = {}", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("Illegal {} = {}", cAlphaFieldNames(4), cAlphaArgs(4)));
# @@ -2603 +2564 @@
# -ShowSevereError(state, cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\"");
# +ShowSevereError(state, format("{}, \"{}\"", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# @@ -2612 +2573 @@
# -ShowSevereError(state, cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\"");
# +ShowSevereError(state, format("{}, \"{}\"", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# @@ -2643 +2604 @@
# -ShowSevereError(state, cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\"");
# +ShowSevereError(state, format("{}, \"{}\"", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# @@ -2652 +2613 @@
# -ShowSevereError(state, cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\"");
# +ShowSevereError(state, format("{}, \"{}\"", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# @@ -2674,7 +2635,5 @@
# -ShowSevereError(state,
# -std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\",
# missing");
# -ShowContinueError(state, "...required " + cAlphaFieldNames(6) + " is blank.");
# -} else {
# -ShowSevereError(state,
# -std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\",
# invalid");
# -ShowContinueError(state, "...not found " + cAlphaFieldNames(6) + "=\"" + cAlphaArgs(6) + "\".");
# +ShowSevereError(state, format("{}{}=\"{}\", missing", RoutineName, cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...required {} is blank.", cAlphaFieldNames(6)));
# +} else {
# +ShowSevereError(state, format("{}{}=\"{}\", invalid", RoutineName, cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...not found {}=\"{}\".", cAlphaFieldNames(6), cAlphaArgs(6)));
# @@ -2691,2 +2650 @@
# -ShowSevereError(
# -state, std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\",
# invalid");
# +ShowSevereError(state, format("{}{}=\"{}\", invalid", RoutineName, cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# @@ -2709,7 +2667,5 @@
# -ShowSevereError(state,
# -std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\",
# missing");
# -ShowContinueError(state, "...required " + cAlphaFieldNames(7) + " is blank.");
# -} else {
# -ShowSevereError(state,
# -std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\",
# invalid");
# -ShowContinueError(state, "...not found " + cAlphaFieldNames(7) + "=\"" + cAlphaArgs(7) + "\".");
# +ShowSevereError(state, format("{}{}=\"{}\", missing", RoutineName, cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...required {} is blank.", cAlphaFieldNames(7)));
# +} else {
# +ShowSevereError(state, format("{}{}=\"{}\", invalid", RoutineName, cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...not found {}=\"{}\".", cAlphaFieldNames(7), cAlphaArgs(7)));
# @@ -2726,2 +2682 @@
# -ShowSevereError(
# -state, std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\",
# invalid");
# +ShowSevereError(state, format("{}{}=\"{}\", invalid", RoutineName, cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# @@ -2751,4 +2706,2 @@
# -ShowWarningError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", \" " + cNumericFieldNames(19) +
# -"\" is calculated based on");
# -ShowContinueError(state, "...the provided \"" + cNumericFieldNames(18) + "\" value.");
# +ShowWarningError(state, format("{}, \"{}\", \" {}\" is calculated based on", cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name, cNumericFieldNames(19)));
# +ShowContinueError(state, format("...the provided \"{}\" value.", cNumericFieldNames(18)));
# @@ -2758,3 +2711 @@
# -ShowWarningError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", invalid \" " +
# cNumericFieldNames(19) +
# -"\" value.");
# +ShowWarningError(state, format("{}, \"{}\", invalid \" {}\" value.", cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name, cNumericFieldNames(19)));
# @@ -2762 +2713 @@
# -ShowContinueError(state, "...The value is recalculated based on the provided \"" + cNumericFieldNames(18) + "\"
# value.");
# +ShowContinueError(state, format("...The value is recalculated based on the provided \"{}\" value.",
# cNumericFieldNames(18)));
# @@ -2778,3 +2729 @@
# -ShowSevereError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\" " + cAlphaFieldNames(8) +
# -" not found: " + cAlphaArgs(8));
# +ShowSevereError(state, format("{}, \"{}\" {} not found: {}", cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name, cAlphaFieldNames(8), cAlphaArgs(8)));
# @@ -2793,3 +2742 @@
# -ShowSevereError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\" " + cAlphaFieldNames(9) +
# -" not found: " + cAlphaArgs(9));
# +ShowSevereError(state, format("{}, \"{}\" {} not found: {}", cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name, cAlphaFieldNames(9), cAlphaArgs(9)));
# @@ -2816,3 +2763 @@
# -ShowSevereError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\" " + cAlphaFieldNames(10) +
# -" not found:" + cAlphaArgs(10));
# +ShowSevereError(state, format("{}, \"{}\" {} not found:{}", cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name, cAlphaFieldNames(10), cAlphaArgs(10)));
# @@ -2825,3 +2770 @@
# -ShowSevereError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\" " + cAlphaFieldNames(10) +
# -" not found:" + cAlphaArgs(10));
# +ShowSevereError(state, format("{}, \"{}\" {} not found:{}", cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name, cAlphaFieldNames(10), cAlphaArgs(10)));
# @@ -2837,3 +2780 @@
# -ShowWarningError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\" " + cNumericFieldNames(28) +
# -" = 0.0 for defrost strategy = RESISTIVE.");
# +ShowWarningError(state, format("{}, \"{}\" {} = 0.0 for defrost strategy = RESISTIVE.", cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name, cNumericFieldNames(28)));
# @@ -2857,3 +2798,2 @@
# -ShowSevereError(state, cCurrentModuleObject + " = \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\"");
# -//** ShowContinueError(state,  cAlphaFieldNames( 24 ) + " must be entered when " + cAlphaFieldNames( 25 ) + " = "
# + cAlphaArgs( 25 )
# -//);
# +ShowSevereError(state, format("{} = \"{}\"", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +//** ShowContinueError(state, format("{} must be entered when {} = {}{}", cAlphaFieldNames( 24 ),
# cAlphaFieldNames( 25 ), cAlphaArgs( 25 ), //));
# @@ -2863,2 +2803,2 @@
# -ShowSevereError(state, cCurrentModuleObject + " = " + state.dataHVACVarRefFlow->VRF(VRFNum).Name);
# -// ShowContinueError(state,  "Illegal " + cAlphaFieldNames( 25 ) + " = " + cAlphaArgs( 25 ) );
# +ShowSevereError(state, format("{} = {}", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +// ShowContinueError(state, format("Illegal {} = {}", cAlphaFieldNames( 25 ), cAlphaArgs( 25 )));
# @@ -2887,11 +2827,5 @@
# -ShowSevereError(state,
# -std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name +
# -"\", missing");
# -ShowContinueError(state, "...required " + cAlphaFieldNames(Count2Index + 2 * NumCompSpd) + " is blank.");
# -} else {
# -ShowSevereError(state,
# -std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name +
# -"\", invalid");
# -ShowContinueError(state,
# -"...not found " + cAlphaFieldNames(Count2Index + 2 * NumCompSpd) + "=\"" +
# -cAlphaArgs(Count2Index + 2 * NumCompSpd) + "\".");
# +ShowSevereError(state, format("{}{}=\"{}\", missing", RoutineName, cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...required {} is blank.", cAlphaFieldNames(Count2Index + 2 * NumCompSpd)));
# +} else {
# +ShowSevereError(state, format("{}{}=\"{}\", invalid", RoutineName, cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...not found {}=\"{}\".", cAlphaFieldNames(Count2Index + 2 * NumCompSpd),
# cAlphaArgs(Count2Index + 2 * NumCompSpd)));
# ...
# +ShowWarningMessage(state, format("{} \"{}\".", cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum),
# state.dataHVACVarRefFlow->VRF(VRFCond).Name));
# @@ -7574,3 +7346 @@
# -ShowWarningMessage(state,
# -std::string(cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum)) + " \"" +
# -state.dataHVACVarRefFlow->VRF(VRFCond).Name + "\".");
# +ShowWarningMessage(state, format("{} \"{}\".", cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum),
# state.dataHVACVarRefFlow->VRF(VRFCond).Name));
# @@ -7641,3 +7411 @@
# -ShowWarningMessage(state,
# -std::string(cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum)) + " \"" +
# -state.dataHVACVarRefFlow->VRF(VRFCond).Name + "\".");
# +ShowWarningMessage(state, format("{} \"{}\".", cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum),
# state.dataHVACVarRefFlow->VRF(VRFCond).Name));
# @@ -7714,4 +7482 @@
# -ShowFatalError(
# -state,
# -std::string{RoutineName} +
# -": Errors found in getting ZoneHVAC:TerminalUnit:VariableRefrigerantFlow system input. Preceding condition(s)
# causes termination.");
# +ShowFatalError(state, format("{}: Errors found in getting ZoneHVAC:TerminalUnit:VariableRefrigerantFlow system
# input. Preceding condition(s) causes termination.", RoutineName));
# @@ -8385,4 +8150 @@
# -ShowMessage(state,
# -"SizeVRF: Potential issue with equipment sizing for " +
# -DataHVACGlobals::cVRFTUTypes(state.dataHVACVarRefFlow->VRFTU(VRFTUNum).VRFTUType_Num) + ' ' +
# -state.dataHVACVarRefFlow->VRFTU(VRFTUNum).Name);
# +ShowMessage(state, format("SizeVRF: Potential issue with equipment sizing for {} {}",
# DataHVACGlobals::cVRFTUTypes(state.dataHVACVarRefFlow->VRFTU(VRFTUNum).VRFTUType_Num),
# state.dataHVACVarRefFlow->VRFTU(VRFTUNum).Name));
# @@ -8462,4 +8224 @@
# -ShowMessage(state,
# -"SizeVRF: Potential issue with equipment sizing for " +
# -DataHVACGlobals::cVRFTUTypes(state.dataHVACVarRefFlow->VRFTU(VRFTUNum).VRFTUType_Num) + ' ' +
# -state.dataHVACVarRefFlow->VRFTU(VRFTUNum).Name);
# +ShowMessage(state, format("SizeVRF: Potential issue with equipment sizing for {} {}",
# DataHVACGlobals::cVRFTUTypes(state.dataHVACVarRefFlow->VRFTU(VRFTUNum).VRFTUType_Num),
# state.dataHVACVarRefFlow->VRFTU(VRFTUNum).Name));
# @@ -8551,4 +8310 @@
# -ShowMessage(state,
# -"SizeVRF: Potential issue with equipment sizing for " +
# -DataHVACGlobals::cVRFTUTypes(state.dataHVACVarRefFlow->VRFTU(VRFTUNum).VRFTUType_Num) + ' ' +
# -state.dataHVACVarRefFlow->VRFTU(VRFTUNum).Name);
# +ShowMessage(state, format("SizeVRF: Potential issue with equipment sizing for {} {}",
# DataHVACGlobals::cVRFTUTypes(state.dataHVACVarRefFlow->VRFTU(VRFTUNum).VRFTUType_Num),
# state.dataHVACVarRefFlow->VRFTU(VRFTUNum).Name));
# @@ -8726,4 +8482 @@
# -ShowMessage(state,
# -"SizeVRF: Potential issue with equipment sizing for " +
# -std::string(cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum)) + ' ' +
# -state.dataHVACVarRefFlow->VRFTU(VRFCond).Name);
# +ShowMessage(state, format("SizeVRF: Potential issue with equipment sizing for {} {}",
# cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum),
# state.dataHVACVarRefFlow->VRFTU(VRFCond).Name));
# @@ -8776,4 +8529 @@
# -ShowMessage(state,
# -"SizeVRF: Potential issue with equipment sizing for " +
# -std::string(cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum)) + ' ' +
# -state.dataHVACVarRefFlow->VRFTU(VRFCond).Name);
# +ShowMessage(state, format("SizeVRF: Potential issue with equipment sizing for {} {}",
# cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum),
# state.dataHVACVarRefFlow->VRFTU(VRFCond).Name));
# @@ -8934,4 +8684 @@
# -ShowMessage(state,
# -"SizeVRF: Potential issue with equipment sizing for " +
# -std::string(cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum)) + ' ' +
# -state.dataHVACVarRefFlow->VRFTU(VRFCond).Name);
# +ShowMessage(state, format("SizeVRF: Potential issue with equipment sizing for {} {}",
# cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum),
# state.dataHVACVarRefFlow->VRFTU(VRFCond).Name));
# @@ -8946,4 +8693 @@
# -ShowMessage(state,
# -"SizeVRF: Potential issue with equipment sizing for " +
# -std::string(cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum)) + ' ' +
# -state.dataHVACVarRefFlow->VRFTU(VRFCond).Name);
# +ShowMessage(state, format("SizeVRF: Potential issue with equipment sizing for {} {}",
# cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum),
# state.dataHVACVarRefFlow->VRFTU(VRFCond).Name));
# @@ -8989,4 +8733 @@
# -ShowMessage(state,
# -"SizeVRF: Potential issue with equipment sizing for " +
# -std::string(cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum)) + ' ' +
# -state.dataHVACVarRefFlow->VRFTU(VRFCond).Name);
# +ShowMessage(state, format("SizeVRF: Potential issue with equipment sizing for {} {}",
# cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum),
# state.dataHVACVarRefFlow->VRFTU(VRFCond).Name));
# @@ -9029,4 +8770 @@
# -ShowMessage(state,
# -"SizeVRF: Potential issue with equipment sizing for " +
# -std::string(cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum)) + ' ' +
# -state.dataHVACVarRefFlow->VRFTU(VRFCond).Name);
# +ShowMessage(state, format("SizeVRF: Potential issue with equipment sizing for {} {}",
# cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum),
# state.dataHVACVarRefFlow->VRFTU(VRFCond).Name));
# @@ -9072,4 +8810 @@
# -ShowMessage(state,
# -"SizeVRF: Potential issue with equipment sizing for " +
# -std::string(cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum)) + ' ' +
# -state.dataHVACVarRefFlow->VRFTU(VRFCond).Name);
# +ShowMessage(state, format("SizeVRF: Potential issue with equipment sizing for {} {}",
# cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum),
# state.dataHVACVarRefFlow->VRFTU(VRFCond).Name));
# @@ -9180 +8915 @@
# -ShowContinueError(state, "... occurs in AirConditioner:VariableRefrigerantFlow object=" + this->Name);
# +ShowContinueError(state, format("... occurs in AirConditioner:VariableRefrigerantFlow object={}", this->Name));
# @@ -9520 +9255 @@
# -ShowWarningMessage(state, DataHVACGlobals::cVRFTUTypes(this->VRFTUType_Num) + " \"" + this->Name + "\"");
# +ShowWarningMessage(state, format("{} \"{}\"", DataHVACGlobals::cVRFTUTypes(this->VRFTUType_Num), this->Name));
# @@ -9549 +9284 @@
# -ShowWarningMessage(state, DataHVACGlobals::cVRFTUTypes(this->VRFTUType_Num) + " \"" + this->Name + "\"");
# +ShowWarningMessage(state, format("{} \"{}\"", DataHVACGlobals::cVRFTUTypes(this->VRFTUType_Num), this->Name));
# @@ -9570 +9305 @@
# -ShowWarningMessage(state, DataHVACGlobals::cVRFTUTypes(this->VRFTUType_Num) + " \"" + this->Name + "\"");
# +ShowWarningMessage(state, format("{} \"{}\"", DataHVACGlobals::cVRFTUTypes(this->VRFTUType_Num), this->Name));
# @@ -10067 +9802 @@
# -ShowSevereError(state, "isVRFCoilPresent: Could not find VRF TU = \"" + std::string{VRFTUName} + "\"");
# +ShowSevereError(state, format("isVRFCoilPresent: Could not find VRF TU = \"{}\"", VRFTUName));
# @@ -10828 +10563 @@
# -ShowSevereError(state, "GetVRFTUOutAirNodeFromName: Could not find VRF TU = \"" + VRFTUName + "\"");
# +ShowSevereError(state, format("GetVRFTUOutAirNodeFromName: Could not find VRF TU = \"{}\"", VRFTUName));
# @@ -10850 +10585 @@
# -ShowSevereError(state, "GetVRFTUInAirNodeFromName: Could not find VRF TU = \"" + VRFTUName + "\"");
# +ShowSevereError(state, format("GetVRFTUInAirNodeFromName: Could not find VRF TU = \"{}\"", VRFTUName));
# @@ -12228 +11963 @@
# -ShowSevereMessage(state, std::string(cVRFTypes(VRF_HeatPump)) + " \"" + this->Name + "\":");
# +ShowSevereMessage(state, format("{} \"{}\":", cVRFTypes(VRF_HeatPump), this->Name));
# @@ -12773 +12508 @@
# -ShowWarningMessage(state, DataHVACGlobals::cVRFTUTypes(this->VRFTUType_Num) + " \"" + this->Name + "\"");
# +ShowWarningMessage(state, format("{} \"{}\"", DataHVACGlobals::cVRFTUTypes(this->VRFTUType_Num), this->Name));
# @@ -13388 +13123 @@
# -ShowSevereMessage(state, " Unreasonable outdoor unit operational mode for \"" + this->Name + "\":");
# +ShowSevereMessage(state, format(" Unreasonable outdoor unit operational mode for \"{}\":", this->Name));
# @@ -13462 +13197 @@
# -ShowSevereMessage(state, " Unreasonable outdoor unit operational mode for \"" + this->Name + "\":");
# +ShowSevereMessage(state, format(" Unreasonable outdoor unit operational mode for \"{}\":", this->Name));
# @@ -13557 +13292 @@
# -ShowSevereMessage(state, " Unreasonable outdoor unit operational mode for \"" + this->Name + "\":");
# +ShowSevereMessage(state, format(" Unreasonable outdoor unit operational mode for \"{}\":", this->Name));

# %% [markdown]
# # Change width of notebook cells for viewing diffs

# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

notebook_width = '90%'
if notebook_width == '100%':
    width = 184
elif notebook_width == '90%':
    width = 164
else:
    width = 115
# Out:
# <style>.container { width:90% !important; }</style>

# %%
r.show_diff(style_output=True, dedent=True, width=width)
# Out:
# ---
# +++
# @@ -170 +170 @@
# -ShowFatalError(state, "SimulateVRF: VRF Terminal Unit not found=" + std::string{CompName});
# +ShowFatalError(state, format("SimulateVRF: VRF Terminal Unit not found={}", CompName));
# @@ -300 +300 @@
# -ShowFatalError(state, "LocalVRFCondenserFactory: Error getting inputs for object named: " + objectName); // LCOV_EXCL_LINE
# +ShowFatalError(state, format("LocalVRFCondenserFactory: Error getting inputs for object named: {}", objectName)); // LCOV_EXCL_LINE
# @@ -341 +341 @@
# -ShowFatalError(state, "SimVRFCondenserPlant:: Invalid loop connection " + std::string(cVRFTypes(VRF_HeatPump)));
# +ShowFatalError(state, format("SimVRFCondenserPlant:: Invalid loop connection {}", cVRFTypes(VRF_HeatPump)));
# @@ -605 +605 @@
# -ShowSevereMessage(state, std::string(cVRFTypes(VRF_HeatPump)) + " \"" + vrf.Name + "\":");
# +ShowSevereMessage(state, format("{} \"{}\":", cVRFTypes(VRF_HeatPump), vrf.Name));
# @@ -632 +632 @@
# -ShowSevereMessage(state, std::string(cVRFTypes(VRF_HeatPump)) + " \"" + vrf.Name + "\":");
# +ShowSevereMessage(state, format("{} \"{}\":", cVRFTypes(VRF_HeatPump), vrf.Name));
# @@ -668 +668 @@
# -ShowSevereMessage(state, std::string(cVRFTypes(VRF_HeatPump)) + " \"" + vrf.Name + "\":");
# +ShowSevereMessage(state, format("{} \"{}\":", cVRFTypes(VRF_HeatPump), vrf.Name));
# @@ -694 +694 @@
# -ShowSevereMessage(state, std::string(cVRFTypes(VRF_HeatPump)) + " \"" + vrf.Name + "\":");
# +ShowSevereMessage(state, format("{} \"{}\":", cVRFTypes(VRF_HeatPump), vrf.Name));
# @@ -776 +776 @@
# -ShowSevereMessage(state, std::string(cVRFTypes(VRF_HeatPump)) + " \"" + vrf.Name + "\":");
# +ShowSevereMessage(state, format("{} \"{}\":", cVRFTypes(VRF_HeatPump), vrf.Name));
# @@ -818 +818 @@
# -ShowSevereMessage(state, std::string(cVRFTypes(VRF_HeatPump)) + " \"" + vrf.Name + "\":");
# +ShowSevereMessage(state, format("{} \"{}\":", cVRFTypes(VRF_HeatPump), vrf.Name));
# @@ -891 +891 @@
# -ShowSevereMessage(state, std::string(cVRFTypes(VRF_HeatPump)) + " \"" + vrf.Name + "\":");
# +ShowSevereMessage(state, format("{} \"{}\":", cVRFTypes(VRF_HeatPump), vrf.Name));
# @@ -1366,3 +1366 @@
# -ShowFatalError(state,
# -std::string{RoutineName} +
# -"Errors found in getting AirConditioner:VariableRefrigerantFlow system input. Preceding condition(s) causes termination.");
# +ShowFatalError(state, format("{}Errors found in getting AirConditioner:VariableRefrigerantFlow system input. Preceding condition(s) causes termination.",
# RoutineName));
# @@ -1640,2 +1638,2 @@
# -ShowSevereError(state, cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\" invalid data");
# -ShowContinueError(state, "Invalid-not found " + cAlphaFieldNames(2) + "=\"" + cAlphaArgs(2) + "\".");
# +ShowSevereError(state, format("{}=\"{}\" invalid data", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("Invalid-not found {}=\"{}\".", cAlphaFieldNames(2), cAlphaArgs(2)));
# @@ -1798,3 +1796,2 @@
# -ShowWarningError(
# -state, std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", invalid");
# -ShowContinueError(state, "..." + cAlphaFieldNames(12) + "=\"" + cAlphaArgs(12) + "\" has out of range values.");
# +ShowWarningError(state, format("{}{}=\"{}\", invalid", RoutineName, cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...{}=\"{}\" has out of range values.", cAlphaFieldNames(12), cAlphaArgs(12)));
# @@ -1808,3 +1805,2 @@
# -ShowWarningError(
# -state, std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", invalid");
# -ShowContinueError(state, "..." + cAlphaFieldNames(12) + " = " + cAlphaArgs(12) + " has out of range value.");
# +ShowWarningError(state, format("{}{}=\"{}\", invalid", RoutineName, cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...{} = {} has out of range value.", cAlphaFieldNames(12), cAlphaArgs(12)));
# @@ -1828 +1824 @@
# -ShowSevereError(state, cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\"");
# +ShowSevereError(state, format("{}, \"{}\"", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# @@ -1936,3 +1932 @@
# -ShowSevereError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\" illegal " + cAlphaFieldNames(19) +
# -" input for this object = " + cAlphaArgs(19));
# +ShowSevereError(state, format("{}, \"{}\" illegal {} input for this object = {}", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name,
# cAlphaFieldNames(19), cAlphaArgs(19)));
# @@ -2006,3 +2000,2 @@
# -ShowWarningError(
# -state, std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", invalid");
# -ShowContinueError(state, "..." + cAlphaFieldNames(23) + "=\"" + cAlphaArgs(23) + "\" has out of range values.");
# +ShowWarningError(state, format("{}{}=\"{}\", invalid", RoutineName, cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...{}=\"{}\" has out of range values.", cAlphaFieldNames(23), cAlphaArgs(23)));
# @@ -2016,3 +2009,2 @@
# -ShowWarningError(
# -state, std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", invalid");
# -ShowContinueError(state, "..." + cAlphaFieldNames(23) + " = " + cAlphaArgs(23) + " has out of range value.");
# +ShowWarningError(state, format("{}{}=\"{}\", invalid", RoutineName, cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...{} = {} has out of range value.", cAlphaFieldNames(23), cAlphaArgs(23)));
# @@ -2034,3 +2026,2 @@
# -ShowWarningError(
# -state, std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", invalid");
# -ShowContinueError(state, "..." + cAlphaFieldNames(9) + " = " + cAlphaArgs(9) + " has out of range value.");
# +ShowWarningError(state, format("{}{}=\"{}\", invalid", RoutineName, cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...{} = {} has out of range value.", cAlphaFieldNames(9), cAlphaArgs(9)));
# @@ -2044,3 +2035,2 @@
# -ShowWarningError(
# -state, std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", suspicious");
# -ShowContinueError(state, "..." + cAlphaFieldNames(9) + " = " + cAlphaArgs(9) + " has unexpected value.");
# +ShowWarningError(state, format("{}{}=\"{}\", suspicious", RoutineName, cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...{} = {} has unexpected value.", cAlphaFieldNames(9), cAlphaArgs(9)));
# @@ -2057,3 +2047,2 @@
# -ShowWarningError(
# -state, std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", invalid");
# -ShowContinueError(state, "..." + cAlphaFieldNames(20) + " = " + cAlphaArgs(20) + " has out of range value.");
# +ShowWarningError(state, format("{}{}=\"{}\", invalid", RoutineName, cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...{} = {} has out of range value.", cAlphaFieldNames(20), cAlphaArgs(20)));
# @@ -2067,3 +2056,2 @@
# -ShowWarningError(
# -state, std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", suspicious");
# -ShowContinueError(state, "..." + cAlphaFieldNames(20) + " = " + cAlphaArgs(20) + " has unexpected value.");
# +ShowWarningError(state, format("{}{}=\"{}\", suspicious", RoutineName, cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...{} = {} has unexpected value.", cAlphaFieldNames(20), cAlphaArgs(20)));
# @@ -2089,2 +2077,2 @@
# -ShowSevereError(state, cCurrentModuleObject + " = \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\"");
# -ShowContinueError(state, cAlphaFieldNames(24) + " must be entered when " + cAlphaFieldNames(25) + " = " + cAlphaArgs(25));
# +ShowSevereError(state, format("{} = \"{}\"", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("{} must be entered when {} = {}", cAlphaFieldNames(24), cAlphaFieldNames(25), cAlphaArgs(25)));
# @@ -2094,2 +2082,2 @@
# -ShowSevereError(state, cCurrentModuleObject + " = " + state.dataHVACVarRefFlow->VRF(VRFNum).Name);
# -ShowContinueError(state, "Illegal " + cAlphaFieldNames(25) + " = " + cAlphaArgs(25));
# +ShowSevereError(state, format("{} = {}", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("Illegal {} = {}", cAlphaFieldNames(25), cAlphaArgs(25)));
# @@ -2102,3 +2090,3 @@
# -ShowSevereError(state, cCurrentModuleObject + " = " + state.dataHVACVarRefFlow->VRF(VRFNum).Name);
# -ShowContinueError(state, "..." + cAlphaFieldNames(26) + " = " + cAlphaArgs(26) + " not found.");
# -ShowContinueError(state, "A schedule name is required when " + cAlphaFieldNames(25) + " = " + cAlphaArgs(25));
# +ShowSevereError(state, format("{} = {}", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...{} = {} not found.", cAlphaFieldNames(26), cAlphaArgs(26)));
# +ShowContinueError(state, format("A schedule name is required when {} = {}", cAlphaFieldNames(25), cAlphaArgs(25)));
# @@ -2112,2 +2100,2 @@
# -ShowSevereError(state, cCurrentModuleObject + " = \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\"");
# -ShowContinueError(state, cAlphaFieldNames(27) + " = " + cAlphaArgs(27) + " not found.");
# +ShowSevereError(state, format("{} = \"{}\"", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("{} = {} not found.", cAlphaFieldNames(27), cAlphaArgs(27)));
# @@ -2124,2 +2112,2 @@
# -ShowSevereError(state, cCurrentModuleObject + " = " + state.dataHVACVarRefFlow->VRF(VRFNum).Name);
# -ShowContinueError(state, "Illegal " + cAlphaFieldNames(28) + " = " + cAlphaArgs(28));
# +ShowSevereError(state, format("{} = {}", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("Illegal {} = {}", cAlphaFieldNames(28), cAlphaArgs(28)));
# @@ -2171,3 +2159 @@
# -ShowSevereError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\" " + cAlphaFieldNames(31) +
# -" not found: " + cAlphaArgs(31));
# +ShowSevereError(state, format("{}, \"{}\" {} not found: {}", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name, cAlphaFieldNames(31),
# cAlphaArgs(31)));
# @@ -2186,3 +2172 @@
# -ShowSevereError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\" " + cAlphaFieldNames(32) +
# -" not found: " + cAlphaArgs(32));
# +ShowSevereError(state, format("{}, \"{}\" {} not found: {}", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name, cAlphaFieldNames(32),
# cAlphaArgs(32)));
# @@ -2208,3 +2192 @@
# -ShowSevereError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\" " + cAlphaFieldNames(33) +
# -" not found:" + cAlphaArgs(33));
# +ShowSevereError(state, format("{}, \"{}\" {} not found:{}", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name, cAlphaFieldNames(33),
# cAlphaArgs(33)));
# @@ -2216,3 +2198 @@
# -ShowSevereError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\" " + cAlphaFieldNames(33) +
# -" not found:" + cAlphaArgs(33));
# +ShowSevereError(state, format("{}, \"{}\" {} not found:{}", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name, cAlphaFieldNames(33),
# cAlphaArgs(33)));
# @@ -2227,3 +2207 @@
# -ShowWarningError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\" " + cNumericFieldNames(21) +
# -" = 0.0 for defrost strategy = RESISTIVE.");
# +ShowWarningError(state, format("{}, \"{}\" {} = 0.0 for defrost strategy = RESISTIVE.", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name,
# cNumericFieldNames(21)));
# @@ -2243,3 +2221,3 @@
# -ShowSevereError(state, cCurrentModuleObject + " = " + state.dataHVACVarRefFlow->VRF(VRFNum).Name);
# -ShowContinueError(state, cAlphaFieldNames(34) + " = " + cAlphaArgs(34));
# -ShowContinueError(state, "Illegal " + cAlphaFieldNames(19) + " input for this object = " + cAlphaArgs(19));
# +ShowSevereError(state, format("{} = {}", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("{} = {}", cAlphaFieldNames(34), cAlphaArgs(34)));
# +ShowContinueError(state, format("Illegal {} input for this object = {}", cAlphaFieldNames(19), cAlphaArgs(19)));
# @@ -2247 +2225 @@
# -ShowContinueError(state, "... " + cAlphaFieldNames(19) + " will be reset to DRYBULBTEMPERATURE and simulation continues.");
# +ShowContinueError(state, format("... {} will be reset to DRYBULBTEMPERATURE and simulation continues.", cAlphaFieldNames(19)));
# @@ -2251,2 +2229,2 @@
# -ShowSevereError(state, cCurrentModuleObject + " = " + state.dataHVACVarRefFlow->VRF(VRFNum).Name);
# -ShowContinueError(state, "Illegal " + cAlphaFieldNames(34) + " = " + cAlphaArgs(34));
# +ShowSevereError(state, format("{} = {}", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("Illegal {} = {}", cAlphaFieldNames(34), cAlphaArgs(34)));
# @@ -2277,3 +2255 @@
# -ShowSevereError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\" " + cAlphaFieldNames(35) +
# -" not a valid Outdoor Air Node = " + cAlphaArgs(35));
# +ShowSevereError(state, format("{}, \"{}\" {} not a valid Outdoor Air Node = {}", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name,
# cAlphaFieldNames(35), cAlphaArgs(35)));
# @@ -2315,2 +2291 @@
# -ShowSevereError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\" " + cAlphaFieldNames(36) + " is blank.");
# +ShowSevereError(state, format("{}, \"{}\" {} is blank.", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name, cAlphaFieldNames(36)));
# @@ -2323,4 +2298,2 @@
# -ShowSevereError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\" " + cNumericFieldNames(23) +
# -" is blank.");
# -ShowContinueError(state, "...input is required when " + cAlphaFieldNames(34) + " = " + cAlphaArgs(34));
# +ShowSevereError(state, format("{}, \"{}\" {} is blank.", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name, cNumericFieldNames(23)));
# +ShowContinueError(state, format("...input is required when {} = {}", cAlphaFieldNames(34), cAlphaArgs(34)));
# @@ -2355,3 +2328 @@
# -ShowSevereError(state,
# -cCurrentModuleObject + " = \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", " + cNumericFieldNames(27) +
# -" must be >= 0");
# +ShowSevereError(state, format("{} = \"{}\", {} must be >= 0", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name, cNumericFieldNames(27)));
# @@ -2367,3 +2338 @@
# -ShowWarningError(state,
# -cCurrentModuleObject + " = \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", " + cNumericFieldNames(28) +
# -" is less than 2 deg C. Freezing could occur.");
# +ShowWarningError(state, format("{} = \"{}\", {} is less than 2 deg C. Freezing could occur.", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name,
# cNumericFieldNames(28)));
# @@ -2376,3 +2345 @@
# -ShowWarningError(state,
# -cCurrentModuleObject + " = \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", " + cAlphaFieldNames(38) +
# -" = \"" + cAlphaArgs(38) + "\" was not found.");
# +ShowWarningError(state, format("{} = \"{}\", {} = \"{}\" was not found.", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name, cAlphaFieldNames(38),
# cAlphaArgs(38)));
# @@ -2390,3 +2357 @@
# -ShowSevereError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", " + cAlphaFieldNames(39) +
# -" not found = " + cAlphaArgs(39));
# +ShowSevereError(state, format("{}, \"{}\", {} not found = {}", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name, cAlphaFieldNames(39),
# cAlphaArgs(39)));
# @@ -2408,3 +2373 @@
# -ShowWarningError(state,
# -cCurrentModuleObject + " = \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", " + cNumericFieldNames(29) +
# -" is less than the minimum temperature in heat pump mode.");
# +ShowWarningError(state, format("{} = \"{}\", {} is less than the minimum temperature in heat pump mode.", cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name, cNumericFieldNames(29)));
# @@ -2436,3 +2399 @@
# -ShowWarningError(state,
# -cCurrentModuleObject + " = \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", " + cNumericFieldNames(30) +
# -" is greater than the maximum temperature in heat pump mode.");
# +ShowWarningError(state, format("{} = \"{}\", {} is greater than the maximum temperature in heat pump mode.", cCurrentModuleObject,
# state.dataHVACVarRefFlow->VRF(VRFNum).Name, cNumericFieldNames(30)));
# @@ -2556,2 +2517,2 @@
# -ShowSevereError(state, cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\" invalid data");
# -ShowContinueError(state, "Invalid-not found " + cAlphaFieldNames(2) + "=\"" + cAlphaArgs(2) + "\".");
# +ShowSevereError(state, format("{}=\"{}\" invalid data", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("Invalid-not found {}=\"{}\".", cAlphaFieldNames(2), cAlphaArgs(2)));
# @@ -2565,2 +2526,2 @@
# -ShowSevereError(state, cCurrentModuleObject + " = \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\"");
# -ShowContinueError(state, cAlphaFieldNames(3) + " = " + cAlphaArgs(3) + " not found.");
# +ShowSevereError(state, format("{} = \"{}\"", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("{} = {} not found.", cAlphaFieldNames(3), cAlphaArgs(3)));
# @@ -2579,2 +2540,2 @@
# -ShowSevereError(state, cCurrentModuleObject + " = " + state.dataHVACVarRefFlow->VRF(VRFNum).Name);
# -ShowContinueError(state, "Illegal " + cAlphaFieldNames(4) + " = " + cAlphaArgs(4));
# +ShowSevereError(state, format("{} = {}", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("Illegal {} = {}", cAlphaFieldNames(4), cAlphaArgs(4)));
# @@ -2603 +2564 @@
# -ShowSevereError(state, cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\"");
# +ShowSevereError(state, format("{}, \"{}\"", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# @@ -2612 +2573 @@
# -ShowSevereError(state, cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\"");
# +ShowSevereError(state, format("{}, \"{}\"", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# @@ -2643 +2604 @@
# -ShowSevereError(state, cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\"");
# +ShowSevereError(state, format("{}, \"{}\"", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# @@ -2652 +2613 @@
# -ShowSevereError(state, cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\"");
# +ShowSevereError(state, format("{}, \"{}\"", cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# @@ -2674,7 +2635,5 @@
# -ShowSevereError(state,
# -std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", missing");
# -ShowContinueError(state, "...required " + cAlphaFieldNames(6) + " is blank.");
# -} else {
# -ShowSevereError(state,
# -std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", invalid");
# -ShowContinueError(state, "...not found " + cAlphaFieldNames(6) + "=\"" + cAlphaArgs(6) + "\".");
# +ShowSevereError(state, format("{}{}=\"{}\", missing", RoutineName, cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...required {} is blank.", cAlphaFieldNames(6)));
# +} else {
# +ShowSevereError(state, format("{}{}=\"{}\", invalid", RoutineName, cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...not found {}=\"{}\".", cAlphaFieldNames(6), cAlphaArgs(6)));
# @@ -2691,2 +2650 @@
# -ShowSevereError(
# -state, std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", invalid");
# +ShowSevereError(state, format("{}{}=\"{}\", invalid", RoutineName, cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# @@ -2709,7 +2667,5 @@
# -ShowSevereError(state,
# -std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", missing");
# -ShowContinueError(state, "...required " + cAlphaFieldNames(7) + " is blank.");
# -} else {
# -ShowSevereError(state,
# -std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", invalid");
# -ShowContinueError(state, "...not found " + cAlphaFieldNames(7) + "=\"" + cAlphaArgs(7) + "\".");
# +ShowSevereError(state, format("{}{}=\"{}\", missing", RoutineName, cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...required {} is blank.", cAlphaFieldNames(7)));
# +} else {
# +ShowSevereError(state, format("{}{}=\"{}\", invalid", RoutineName, cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# +ShowContinueError(state, format("...not found {}=\"{}\".", cAlphaFieldNames(7), cAlphaArgs(7)));
# @@ -2726,2 +2682 @@
# -ShowSevereError(
# -state, std::string{RoutineName} + cCurrentModuleObject + "=\"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", invalid");
# +ShowSevereError(state, format("{}{}=\"{}\", invalid", RoutineName, cCurrentModuleObject, state.dataHVACVarRefFlow->VRF(VRFNum).Name));
# @@ -2751,4 +2706,2 @@
# -ShowWarningError(state,
# -cCurrentModuleObject + ", \"" + state.dataHVACVarRefFlow->VRF(VRFNum).Name + "\", \" " + cNumericFieldNames(19) +
# -"\" is calculated based on");
# -ShowContinueError(state, "...the provided \"" + cNumericFieldNames(18) + "\" value.");
# ...
# -"SizeVRF: Potential issue with equipment sizing for " +
# -DataHVACGlobals::cVRFTUTypes(state.dataHVACVarRefFlow->VRFTU(VRFTUNum).VRFTUType_Num) + ' ' +
# -state.dataHVACVarRefFlow->VRFTU(VRFTUNum).Name);
# +ShowMessage(state, format("SizeVRF: Potential issue with equipment sizing for {} {}",
# DataHVACGlobals::cVRFTUTypes(state.dataHVACVarRefFlow->VRFTU(VRFTUNum).VRFTUType_Num), state.dataHVACVarRefFlow->VRFTU(VRFTUNum).Name));
# @@ -8551,4 +8310 @@
# -ShowMessage(state,
# -"SizeVRF: Potential issue with equipment sizing for " +
# -DataHVACGlobals::cVRFTUTypes(state.dataHVACVarRefFlow->VRFTU(VRFTUNum).VRFTUType_Num) + ' ' +
# -state.dataHVACVarRefFlow->VRFTU(VRFTUNum).Name);
# +ShowMessage(state, format("SizeVRF: Potential issue with equipment sizing for {} {}",
# DataHVACGlobals::cVRFTUTypes(state.dataHVACVarRefFlow->VRFTU(VRFTUNum).VRFTUType_Num), state.dataHVACVarRefFlow->VRFTU(VRFTUNum).Name));
# @@ -8726,4 +8482 @@
# -ShowMessage(state,
# -"SizeVRF: Potential issue with equipment sizing for " +
# -std::string(cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum)) + ' ' +
# -state.dataHVACVarRefFlow->VRFTU(VRFCond).Name);
# +ShowMessage(state, format("SizeVRF: Potential issue with equipment sizing for {} {}", cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum),
# state.dataHVACVarRefFlow->VRFTU(VRFCond).Name));
# @@ -8776,4 +8529 @@
# -ShowMessage(state,
# -"SizeVRF: Potential issue with equipment sizing for " +
# -std::string(cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum)) + ' ' +
# -state.dataHVACVarRefFlow->VRFTU(VRFCond).Name);
# +ShowMessage(state, format("SizeVRF: Potential issue with equipment sizing for {} {}", cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum),
# state.dataHVACVarRefFlow->VRFTU(VRFCond).Name));
# @@ -8934,4 +8684 @@
# -ShowMessage(state,
# -"SizeVRF: Potential issue with equipment sizing for " +
# -std::string(cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum)) + ' ' +
# -state.dataHVACVarRefFlow->VRFTU(VRFCond).Name);
# +ShowMessage(state, format("SizeVRF: Potential issue with equipment sizing for {} {}", cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum),
# state.dataHVACVarRefFlow->VRFTU(VRFCond).Name));
# @@ -8946,4 +8693 @@
# -ShowMessage(state,
# -"SizeVRF: Potential issue with equipment sizing for " +
# -std::string(cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum)) + ' ' +
# -state.dataHVACVarRefFlow->VRFTU(VRFCond).Name);
# +ShowMessage(state, format("SizeVRF: Potential issue with equipment sizing for {} {}", cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum),
# state.dataHVACVarRefFlow->VRFTU(VRFCond).Name));
# @@ -8989,4 +8733 @@
# -ShowMessage(state,
# -"SizeVRF: Potential issue with equipment sizing for " +
# -std::string(cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum)) + ' ' +
# -state.dataHVACVarRefFlow->VRFTU(VRFCond).Name);
# +ShowMessage(state, format("SizeVRF: Potential issue with equipment sizing for {} {}", cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum),
# state.dataHVACVarRefFlow->VRFTU(VRFCond).Name));
# @@ -9029,4 +8770 @@
# -ShowMessage(state,
# -"SizeVRF: Potential issue with equipment sizing for " +
# -std::string(cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum)) + ' ' +
# -state.dataHVACVarRefFlow->VRFTU(VRFCond).Name);
# +ShowMessage(state, format("SizeVRF: Potential issue with equipment sizing for {} {}", cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum),
# state.dataHVACVarRefFlow->VRFTU(VRFCond).Name));
# @@ -9072,4 +8810 @@
# -ShowMessage(state,
# -"SizeVRF: Potential issue with equipment sizing for " +
# -std::string(cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum)) + ' ' +
# -state.dataHVACVarRefFlow->VRFTU(VRFCond).Name);
# +ShowMessage(state, format("SizeVRF: Potential issue with equipment sizing for {} {}", cVRFTypes(state.dataHVACVarRefFlow->VRF(VRFCond).VRFSystemTypeNum),
# state.dataHVACVarRefFlow->VRFTU(VRFCond).Name));
# @@ -9180 +8915 @@
# -ShowContinueError(state, "... occurs in AirConditioner:VariableRefrigerantFlow object=" + this->Name);
# +ShowContinueError(state, format("... occurs in AirConditioner:VariableRefrigerantFlow object={}", this->Name));
# @@ -9520 +9255 @@
# -ShowWarningMessage(state, DataHVACGlobals::cVRFTUTypes(this->VRFTUType_Num) + " \"" + this->Name + "\"");
# +ShowWarningMessage(state, format("{} \"{}\"", DataHVACGlobals::cVRFTUTypes(this->VRFTUType_Num), this->Name));
# @@ -9549 +9284 @@
# -ShowWarningMessage(state, DataHVACGlobals::cVRFTUTypes(this->VRFTUType_Num) + " \"" + this->Name + "\"");
# +ShowWarningMessage(state, format("{} \"{}\"", DataHVACGlobals::cVRFTUTypes(this->VRFTUType_Num), this->Name));
# @@ -9570 +9305 @@
# -ShowWarningMessage(state, DataHVACGlobals::cVRFTUTypes(this->VRFTUType_Num) + " \"" + this->Name + "\"");
# +ShowWarningMessage(state, format("{} \"{}\"", DataHVACGlobals::cVRFTUTypes(this->VRFTUType_Num), this->Name));
# @@ -10067 +9802 @@
# -ShowSevereError(state, "isVRFCoilPresent: Could not find VRF TU = \"" + std::string{VRFTUName} + "\"");
# +ShowSevereError(state, format("isVRFCoilPresent: Could not find VRF TU = \"{}\"", VRFTUName));
# @@ -10828 +10563 @@
# -ShowSevereError(state, "GetVRFTUOutAirNodeFromName: Could not find VRF TU = \"" + VRFTUName + "\"");
# +ShowSevereError(state, format("GetVRFTUOutAirNodeFromName: Could not find VRF TU = \"{}\"", VRFTUName));
# @@ -10850 +10585 @@
# -ShowSevereError(state, "GetVRFTUInAirNodeFromName: Could not find VRF TU = \"" + VRFTUName + "\"");
# +ShowSevereError(state, format("GetVRFTUInAirNodeFromName: Could not find VRF TU = \"{}\"", VRFTUName));
# @@ -12228 +11963 @@
# -ShowSevereMessage(state, std::string(cVRFTypes(VRF_HeatPump)) + " \"" + this->Name + "\":");
# +ShowSevereMessage(state, format("{} \"{}\":", cVRFTypes(VRF_HeatPump), this->Name));
# @@ -12773 +12508 @@
# -ShowWarningMessage(state, DataHVACGlobals::cVRFTUTypes(this->VRFTUType_Num) + " \"" + this->Name + "\"");
# +ShowWarningMessage(state, format("{} \"{}\"", DataHVACGlobals::cVRFTUTypes(this->VRFTUType_Num), this->Name));
# @@ -13388 +13123 @@
# -ShowSevereMessage(state, " Unreasonable outdoor unit operational mode for \"" + this->Name + "\":");
# +ShowSevereMessage(state, format(" Unreasonable outdoor unit operational mode for \"{}\":", this->Name));
# @@ -13462 +13197 @@
# -ShowSevereMessage(state, " Unreasonable outdoor unit operational mode for \"" + this->Name + "\":");
# +ShowSevereMessage(state, format(" Unreasonable outdoor unit operational mode for \"{}\":", this->Name));
# @@ -13557 +13292 @@
# -ShowSevereMessage(state, " Unreasonable outdoor unit operational mode for \"" + this->Name + "\":");
# +ShowSevereMessage(state, format(" Unreasonable outdoor unit operational mode for \"{}\":", this->Name));

# %% [markdown]
# ## Run all files

# %%
clang_format(EP_SRC / 'VentilatedSlab.cc')

# %%
EP_SRC
# Out:
# PosixPath('/Users/julien/Software/Others/EnergyPlus2/src/EnergyPlus')

# %%
# %%time
all_reports = []
for fpath in EP_SRC.glob('*.cc'):
    if not fpath.is_file():
        continue
    if not fpath.suffix in ['.cc', '.hh']:
        print(f"Skipping extension for {fpath}")
        continue
    r = fix_format_in_file(file=fpath)
    if r:
        all_reports.append(r)
# Out:
# CPU times: user 691 ms, sys: 501 ms, total: 1.19 s
# Wall time: 13.9 s
